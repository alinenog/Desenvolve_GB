# %% [markdown]
# # <font color='green' style='font-size: 30px backgound =;'> Clustering Básico: k-means, DBSCAN e mean shift - II</font>
# <hr style='border: 2px solid green;'>

# %% [markdown]
# 01-Análise exploratória
