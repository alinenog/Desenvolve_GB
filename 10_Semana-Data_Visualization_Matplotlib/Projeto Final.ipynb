# %% [markdown]
# ### Relatório do mês de maio de 2014

# %%
import pandas as pd 
import datetime
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('monitoramento_tempo.csv')
df['data'] = pd.to_datetime(df['data'])
df.head(2)
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0       282.08   1024.0      81.0               0.0                  0.0
# 1       282.08   1024.0      81.0               0.0                  0.0
#
#   dia_da_semana                data
# 0       Domingo 2012-10-01 12:00:00
# 1       Domingo 2012-10-01 13:00:00

# %%
#Destacando mês maio no 2º eixo
fig = plt.figure(figsize=(15,8))

#Onde altera a posição dos eixos 
eixo = fig.add_axes([0,0,1,1]) #Fazendo eixo geral
eixo2= fig.add_axes([0.7,0.65,0.3,0.3]) #Fazendo eixo de destaque

#Eixo principal
eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g' )
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,330)
eixo.set_title('Temperatura em maio de 2014', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

#conf destaque do mês maio no 2º eixo
azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df ['data'] > datetime.datetime(2014,6,1)

#Eixo de destaque(menor)
eixo2.grid(True)
eixo2.plot(df['data'],df['temperatura'], color = 'g') #todo grafico verde
eixo2.plot(df[azul_esquerda]['data'],df[azul_esquerda]['temperatura'], color='b')#lado esquerdo azul sobreposto
eixo2.plot(df[azul_direita]['data'],df[azul_direita]['temperatura'], color='b')#lado direito azul sobreposto
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ### Relatório de temperatura min. ao max

# %%
#Incluindo anotação temp minimo
fig=plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='g')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20 )
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

# máximo ----------------------------
#local destino 
x1= df['data'][df['temperatura'].idxmax()]
y1= max(df['temperatura'])

#local origem
x2=df['data'][df['temperatura'].idxmax()-7000]
y2=max(df['temperatura']) -5

eixo.annotate("Máximo", xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

# minimo ----------------------------
#local destino 
x1= df['data'][df['temperatura'].idxmin()]
y1= min(df['temperatura'])

#local origem
x2=df['data'][df['temperatura'].idxmin()-7000]
y2=min(df['temperatura']) + 5

eixo.annotate("Minimo", xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(df['temperatura']),color = 'k', linestyle='--')
eixo.axhline(min(df['temperatura']), color= 'k', linestyle='--')

# %% [markdown]
# ### Obter foco de um periodo especifico no grafico

# %%
#Destacando mês maio no 2º eixo
fig = plt.figure(figsize=(15,8))

#Onde altera a posição dos eixos 
eixo = fig.add_axes([0,0,1,1]) #Fazendo eixo geral
eixo2= fig.add_axes([0.7,0.65,0.3,0.3]) #Fazendo eixo de destaque

#Eixo principal
eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = 'g' )
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,330)
eixo.set_title('Temperatura em maio de 2014', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

#conf destaque do mês maio no 2º eixo
azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df ['data'] > datetime.datetime(2014,6,1)

#Eixo de destaque(menor)
eixo2.grid(True)
eixo2.plot(df['data'],df['temperatura'], color = 'g') #todo grafico verde
eixo2.plot(df[azul_esquerda]['data'],df[azul_esquerda]['temperatura'], color='b')#lado esquerdo azul sobreposto
eixo2.plot(df[azul_direita]['data'],df[azul_direita]['temperatura'], color='b')#lado direito azul sobreposto
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ### Grafico Pizza

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo','Segunda','Terça', 'Quarta', 'Quinta','Sexta','Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
# colocando sombra nas fatias explodidas grafico de pizza
#autopct = gera porcentagem | exlodir = explode |shadow='true' = gera sombra


fig=plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir= [0.1,0,0,0,0,0.1,0.1]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%', explode= explodir,shadow='true')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# ### Gráfico de barras

# %%
#Colocando bordas
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color = cores, edgecolor='black')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Segunda'),
#  Text(2, 0, 'Terça'),
#  Text(3, 0, 'Quarta'),
#  Text(4, 0, 'Quinta'),
#  Text(5, 0, 'Sexta'),
#  Text(6, 0, 'Sábado')]

# %% [markdown]
# ### Grafico de dispersão

# %%
#Almentando o tamanho dos marcadores
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'} 
marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'} 

for especie in df['espécie'].unique():
    tmp = df[df['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                 color=cores[especie], marker=marcadores[especie],
                 s=100)

eixo.set_title('Gráfico de dispersão',fontsize=25, pad=15)
eixo.set_xlabel('Compimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'espécie'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\aline\OneDrive\Área de Trabalho\10_Semana-Data_Visualization_parte_2\Data_Visualization_criação_de_gráficos_com o_Matplotlib\Projeto Final.ipynb Cell 15' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=4'>5</a> cores = {'Iris-setosa':'r', 'Iris-versicolor':'b', 'Iris-virginica':'g'}
#       <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=5'>6</a> marcadores = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'v'}
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=7'>8</a> for especie in df['espécie'].unique():
#       <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=8'>9</a>     tmp = df[df['espécie'] == especie]
#      <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=9'>10</a>     eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
#      <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=10'>11</a>                  color=cores[especie], marker=marcadores[especie],
#      <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/%C3%81rea%20de%20Trabalho/10_Semana-Data_Visualization_parte_2/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com%20o_Matplotlib/Projeto%20Final.ipynb#ch0000011?line=11'>12</a>                  s=100)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/aline/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'espécie'

# %% [markdown]
# ### Grafico de distribuição dos dados

# %%
import numpy as np
df = pd.read_csv('iris.csv')
df.head(2)
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

cores= ['red', 'blue', 'orange', 'green']

caixas = eixo.boxplot(df.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15,pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1).columns)

for caixa, cor in zip(caixas['boxes'], cores):
    caixa.set(color=cor)
    
for outlier in caixas['fliers']:
    outlier.set(marker='x', markersize = 8)

# %% [markdown]
# ### Visualisação de Histograma

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df['comprimento_pétala'], bins=20,density=True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %% [markdown]
# ### Combinando as 3 imagens

# %%
from PIL import Image

largura, altura = Image.open('histograma_ivg.png').size
combinada = Image.new("RGB", (3*largura, altura))
intervalo = 0
for imagem in map(Image.open, ['histograma_iv.png', 'histograma_is.png', 
                               'histograma_ivg.png']):
    
    combinada.paste(imagem, (intervalo, 0))
    intervalo += largura
combinada.save('combinada.png')

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1176x361 at 0x23FD740B130>
